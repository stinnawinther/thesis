# %%
#Install packages:
import numpy as np
import matplotlib as plt
import pandas as pd
import math
import csv

# %%
#Read in the csv file:
df = pd.read_csv("Data_Entry_2017_v2020.csv")

# %%
df
# Out:
#              Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0       00000001_000.png            Cardiomegaly            0           1
# 1       00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2       00000001_002.png   Cardiomegaly|Effusion            2           1
# 3       00000002_000.png              No Finding            0           2
# 4       00000003_001.png                  Hernia            0           3
# ...                  ...                     ...          ...         ...
# 112115  00030801_001.png          Mass|Pneumonia            1       30801
# 112116  00030802_000.png              No Finding            0       30802
# 112117  00030803_000.png              No Finding            0       30803
# 112118  00030804_000.png              No Finding            0       30804
# 112119  00030805_000.png              No Finding            0       30805
#
#         Patient Age Patient Gender View Position  OriginalImage[Width  \
# ...

# %%
#Get mean, max, min and std. deviation on age.
df['Patient Age'].describe()
# Out:
# count    112120.000000
# mean         46.626365
# std          16.602680
# min           0.000000
# 25%          34.000000
# 50%          49.000000
# 75%          59.000000
# max          95.000000
# Name: Patient Age, dtype: float64

# %%
#Group by gender:
Gender_df = df.groupby(df['Patient Gender'])['Image Index'].count().reset_index()

# %%
Gender_df
# Out:
#   Patient Gender  Image Index
# 0              F        48780
# 1              M        63340

# %%
#Calculate the percentage of female/male:
Gender_df['percent']= (Gender_df['Image Index']/112120*100)

# %%
Gender_df
# Out:
#   Patient Gender  Image Index    percent
# 0              F        48780  43.506957
# 1              M        63340  56.493043

# %%
#Find unique view positions:
df['View Position'].unique()
# Out:
# array(['PA', 'AP'], dtype=object)
