# %%
#Install packages:
import numpy as np
import matplotlib as plt
import pandas as pd
import math
import csv

# %%
df_images = pd.read_csv('Figure1_covidX_metadata.csv')

# %%
df_images
# Out:
#        patientid  offset  sex        age     finding  survival temperature  \
# 0    COVID-00001    13.0    M         33    COVID-19       NaN         NaN
# 1    COVID-00002     NaN    M        50+         NaN       NaN         NaN
# 2   COVID-00003a     8.0    M         28         NaN       NaN        39.1
# 3   COVID-00003b     8.0    M         28         NaN       NaN        39.1
# 4    COVID-00004     2.0    M         42    COVID-19       NaN         NaN
# 5    COVID-00005     NaN  NaN        NaN         NaN       NaN         NaN
# 6    COVID-00006     5.0    F         57    COVID-19       NaN         NaN
# 7    COVID-00007     NaN  NaN         73         NaN       NaN         38+
# 8    COVID-00008     4.0    M         47    COVID-19       NaN         NaN
# 9    COVID-00009     NaN  NaN        NaN    COVID-19       NaN         NaN
# 10   COVID-00010     5.0    M        50+         NaN       NaN         NaN
# ...

# %%
df_images.count()
# Out:
# patientid               55
# offset                  20
# sex                     22
# age                     29
# finding                 40
# survival                 0
# temperature              4
# pO2 saturation          12
# view                    18
# modality                55
# artifacts/distortion     7
# notes                   48
# dtype: int64

# %%
#missing values  - sex
df_images['sex'].isna().sum()
# Out:
# 33

# %%
df_images['age'].isna().sum()
# Out:
# 26

# %%
df_images['view'].isna().sum()
# Out:
# 37
