# %%
#install openAlex API:
import sys
# !{sys.executable} -m pip install openalexapi

# %%
#Install packages:
import numpy as np
import matplotlib as plt
import pandas as pd

# %% [markdown]
#  # Experiment with queries through openalex

# %%
#Try search queries:

#Here: chest radiology and AI:
SEARCH_URL = 'https://api.openalex.org/works?filter=abstract.search:chest&filter=abstract.search:radiology&filter=abstract.search:AI'

#Here: chest xray and AI:
SEARCH_URL1 = 'https://api.openalex.org/works?filter=abstract.search:chest&filter=abstract.search:xray&filter=abstract.search:AI'

#Here I search for CXR and AI: 
SEARCH_URL2 = 'https://api.openalex.org/works?filter=abstract.search:CXR&filter=abstract.search:AI'

#Here Chest xray and deep learning:
SEARCH_URL3 = 'https://api.openalex.org/works?filter=abstract.search:chest&filter=abstract.search:xray&filter=abstract.search:deep&filter=abstract.search:learning'

#Here CXR and deep learning:
SEARCH_URL4 = 'https://api.openalex.org/works?filter=abstract.search:CXR&filter=abstract.search:deep&filter=abstract.search:learning'

#Here CXR and machine learning:
SEARCH_URL5 = 'https://api.openalex.org/works?filter=abstract.search:CXR&filter=abstract.search:machine&filter=abstract.search:learning'

#Here Chest xray and machine learning:
SEARCH_URL6 = 'https://api.openalex.org/works?filter=abstract.search:chest&filter=abstract.search:xray&filter=abstract.search:machine&filter=abstract.search:learning'

# %%
#get the requests
import requests
import io
response = requests.get(url=SEARCH_URL)

response.raise_for_status()
searched_work = response.json()

# %%
response1 = requests.get(url=SEARCH_URL1)

response1.raise_for_status()
searched_work1 = response1.json()

# %%
response2 = requests.get(url=SEARCH_URL2)

response2.raise_for_status()
searched_work2 = response2.json()

# %%
response3 = requests.get(url=SEARCH_URL3)

response3.raise_for_status()
searched_work3 = response3.json()

# %%
response4 = requests.get(url=SEARCH_URL4)

response4.raise_for_status()
searched_work4 = response4.json()

# %%
response5 = requests.get(url=SEARCH_URL5)

response5.raise_for_status()
searched_work5 = response5.json()

# %%
response6 = requests.get(url=SEARCH_URL6)

response6.raise_for_status()
searched_work6 = response6.json()

# %%
#save the results as data frame (ignoring the metadata)
df0 = pd.DataFrame(searched_work['results'])
df1 = pd.DataFrame(searched_work1['results'])
df2 = pd.DataFrame(searched_work2['results'])
df3 = pd.DataFrame(searched_work3['results'])
df4 = pd.DataFrame(searched_work4['results'])
df5 = pd.DataFrame(searched_work5['results'])
df6 = pd.DataFrame(searched_work6['results'])

# %%
#reset index to id to concat the dataframes:
df0 = df0.set_index('id')
df1 = df1.set_index('id')
df2 = df2.set_index('id')
df3 = df3.set_index('id')
df4 = df4.set_index('id')
df5 = df5.set_index('id')
df6 = df6.set_index('id')

# %%
#concat the dataframe:
df = pd.concat([df1, df2])
#, df3, df4, df5, df6

# %%
#reset index and drop duplicates, set index to id and sort index:
df = (df.reset_index()
        .drop_duplicates(subset='id', keep='last')
        .set_index('id').sort_index())

# %%
df
# Out:
#                                                                                 doi  \
# id
# https://openalex.org/W1260204519         https://doi.org/10.1016/j.jacc.2008.07.031
# https://openalex.org/W130099911               https://doi.org/10.1056/nejmoa1102873
# https://openalex.org/W1966756689             https://doi.org/10.1002/art.1780270401
# https://openalex.org/W1968938835                https://doi.org/10.1542/peds.99.1.1
# https://openalex.org/W1969679036        https://doi.org/10.1016/j.chest.2016.02.643
# https://openalex.org/W1981125577                     https://doi.org/10.1086/514546
# https://openalex.org/W1984981910   https://doi.org/10.1097/00005373-199709000-00003
# https://openalex.org/W1988014376      https://doi.org/10.1016/j.lungcan.2004.06.007
# https://openalex.org/W1994062553           https://doi.org/10.1109/tmi.2013.2290491
# https://openalex.org/W1996667945                  https://doi.org/10.1159/000029539
# ...

# %%
"As long as we have CXR and chest Xray it gives gives the 49 results.
"It does not change anything if using chest xray or chest radiology - it gives the same results"
"Furthermore doesn't change anything, if the second word is AI, Machine learning or Deep learning.
